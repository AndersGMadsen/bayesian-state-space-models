# %%
from utils import *

# %%
model = StateSpaceModel()

# %%
Q = model.Q
R = model.R
A = model.A
H = model.H

linear = CarTrajectoryLinear(Q, R, A, H)
data = linear.get_data()

f = model.f
h = model.h

nonlinear = CarTrajectoryNonLinear(Q, R, f, h)
#data = nonlinear.get_data()

# %%
import matplotlib.pyplot as plt

plt.plot(data[0][:, 0], data[0][:, 1])
